# %% [markdown]
# # Introduction to Causal Inference
#
# ---

# %% [markdown]
# ### Correlation ≠ Causation
#
# *A Pacific island tribe observed that healthy people had lice, while sick people did not. Accordingly, they believed that lice infestations are good for one’s health.*
#
# Of course, lice do not cause good health
#
# Causality runs the other way: lice abandon a fevered body to seek a healthier host

# %% [markdown]
# ### Correlation → Causation?
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### A Simple Causal Graph
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Spurious Correlations
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Reverse Causality
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Omitted Variable Bias (or Selection Bias)
#
# ![image.png](attachment:image.png)
# confounder that jointly determines D and Y.
#
# ![image-2.png](attachment:image-2.png)
# - If we don't account for the effects of this third variable in some way, we will obtain a biased estimate of the relationship between D and Y.
# - This bias is called omitted variable bias because we leave out one or more relevant variables in our model.

# %% [markdown]
# ### Should You Get Health Insurance (or Not)?
#
# - Suppose the decision of getting health insurance is a matter of ...
#     • Insurance premium
#     • Quality of care
#
# - You observe a strong, long-term correlation between having health insurance and positive health outcomes
#
# > Should you get health insurance?

# %% [markdown]
# ### Many Possible Mechanisms, Which One Is It?
#
# - Being uninsured may lead to poorer health outcomes → causal effect
# - Poor health may lead to loss of health insurance → reverse causality
# - Uninsured may be more adventurous or less concerned about their health → selection
# bias
#
# > All of these hypotheses could account for the observed correlation

# %% [markdown]
# ### Why Causality Matters
#
# - Identifying true cause is crucial because each explanation gives different advice
# - Machine learning and large data sets may help us predict what will happen
# - But even the most sophisticated machine learning tools cannot make the data tell us why
#
# > “We live in an era that presumes Big Data to be the solution to all our problems”
# > (Pearl, The Book of Why)

# %% [markdown]
# ### How Can We Learn About Causality?
#
# - What is the causal impact of health insurance on your health?
# - Causal effect = (your health outcome with insurance) − (your health outcome without insurance) ... holding **all other factors constant**
#
# • Ideally, we would clone you and measure your and your clone’s health under different insurance conditions
#
# • In reality, we either observe you with or without health insurance, but never both

# %% [markdown]
# ### What is Causal Inference?
#
# - Counterfactual outcome = What would have happened had this one aspect not changed
# - We never observe the counterfactual → **fundamental problem of causal inference** (Holland, 1986)
# - Causal inference is about how we can use **data + assumptions** to learn something about the counterfactual
