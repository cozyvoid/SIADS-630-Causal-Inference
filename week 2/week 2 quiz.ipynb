# %% [markdown]
# # Week 2 Quiz
#
# ---

# %% [markdown]
# ### 1. The Conditional Independence Assumption (CIA) motivates causal identification strategies like matching and regression.
#
# ### Which of the following is true about the CIA?
#
# - [ ] CIA states that potential outcomes are independent of observable characteristics (covariates) conditional on treatment status.
# - [ ] CIA is always a plausible assumption to make.
# - [ ] We can test the CIA by checking for covariate balance.
# - [x] CIA states that the treatment is “as good as random”, once we control for certain covariates.

# %% [markdown]
# CIA means that after conditioning on relevant observed covariates, treatment assignment is independent of potential outcomes.

# %% [markdown]
# ### 2. We would like to investigate whether drinking coffee causes stress. Suppose we have data on  employees working in the same workplace, some of whom drink coffee and others don’t. We assume that conditional on age and gender, drinking coffee is “as good as random”.
#
# ### Using exact matching on age and gender, calculate the ATT. (For simplicity, we will assume reverse causality, i.e. stress causing people to drink more coffee, is not an issue.) (Round to two decimal places.)
#
# ![image.png](attachment:image.png)
#
# - [x] 2
# - [ ] 1.7
# - [ ] 0.9
# - [ ] 1.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Consider the same context (coffee-stress) from question 2. This time calculate the ATT using propensity score matching. (For simplicity, we will assume reverse causality, i.e. stress causing people to drink more coffee, is not an issue.) (Round to two decimal places.)
#
# ![image.png](attachment:image.png)
#
# - [ ] 0.9
# - [ ] 2
# - [ ] 1.7
# - [x] 1.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Which of the following is true about matching?
#
# - [x] Exact matching is based on perfect matches. If we want to estimate the ATT, we look for control units with the same covariates as the treated units.
# - [ ] Propensity score matching uses the Mahalanobis distance metric to match treated units with control units (and vice versa).
# - [ ] Matching addresses selection on both observables and unobservables.
# - [ ] Matching allows us to estimate the average treatment effect on the treated (ATT), but not the average treatment effect (ATE).

# %% [markdown]
# Exact matching is based on perfect matches. If we want to estimate the ATT, we look for control units with the same covariates as the treated units.

# %% [markdown]
# ### 5. Which of the following is/are true about regression? Select all that apply.
#
# - [x] Ordinary least squares (OLS) regression minimizes the (average of the) mean squared prediction error, i.e. the difference between observed Y and the value predicted by the sample regression model.
# - [ ] Regression can only estimate linear relationships.
# - [x] A fitted value of $Y_i$ is the value our model predicts given a particular value of $X_i = x$.
# - [ ] The conditional expectation function provides the best linear approximation of the population regression function.

# %% [markdown]
# Answers:
#
# - Ordinary least squares regression minimizes the mean squared prediction error.
# - A fitted value of $Y_i$ is the value our model predicts given $X_i = x$.
#
# Regression is not limited to purely linear relationships because we can include transformations, interactions, and nonlinear terms.

# %% [markdown]
# ### 6. We are interested in the relationship between writing score, and gender, reading score, math score; so we run a regression.
#
# ### Based on the regression table below, which of the following are correct interpretations of the results. Select all that apply. (lgwrite: natural log of writing score, lgmath: natural log of math score, female: dummy variable that is equal to 1 for females, 0 for males, read: reading score)
#
# ![image.png](attachment:image.png)
#
# - [ ] A 1% increase in reading score is associated with a 0.006 unit increase in writing score.
# - [x] A 1 unit increase in the reading score is associated with about a 0.7% increase in writing score.
# - [ ] A 1% increase in math score is associated with a 0.4 unit increase in writing score.
# - [x] A 1% increase in math score is associated with a 0.4% increase in writing score.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7. Which of the below is true about zero conditional mean assumption? Select all that apply.
#
# - [x] In practice, the constant variance assumption for the errors of the population regression (i.e. “homoskedasticity”) is often violated and commonly fixed by estimating “robust” standard errors.
# - [x] The smaller the size of the residual, the better we are at predicting $Y_i$, i.e. data points are closer to the sample regression line.
# - [x] We don’t observe the variance of the errors of the population regression, but we can use the residuals to estimate it.
# - [ ] Smaller standard errors allow regression coefficients to be interpreted as the causal effect of a unit increase in X on the

# %% [markdown]
# Answers:
# - In practice, the constant variance assumption is often violated and commonly fixed by estimating robust standard errors.
# - The smaller the residual, the better we are at predicting $Y_i$
# - We do not observe the variance of the population errors, but we can use residuals to estimate it.
#
# Smaller standard errors do not automatically make a coefficient causal.

# %% [markdown]
# ### 8. Which of the below is/are true about residual and error term? Select all that apply.
#
# - [x] Suppose we regress the number of stars on the (natural log of) number of reviews for recipes on a cooking website, where the error term captures, among other things, unobserved quality of the recipes. Zero conditional mean requires that the average quality is the same for recipes with 12 reviews and for recipes with 1,
# - [x] It allows the regression coefficient of X to be interpreted as the causal effect of X on the outcome Y.
# - [ ] The zero conditional mean is testable.
# - [ ] The zero conditional mean is most plausible when $X_i$ is correlated with the error term $u_i$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 9. We want to investigate whether drinking coffee causes stress. We have data coming from two different workplaces, an energy trading desk and a yoga studio. The trading desk causes its employees a lot of stress and provides them with an unlimited supply of free coffee.
#
# ### Based on the regression models below, which of the following is/are true? Select all that apply. (For simplicity, we will assume reverse causality, i.e. stress causing people to drink more coffee, is not an issue.)
#
# i. $stress_i = \alpha^l + \beta^l coffee_i + \sigma^l age_i + \theta^l male_i + \gamma^l trader_i + u_i^l$
#
# ii. $stress_i = \alpha^2 + \beta^s coffee_i + \sigma^s age_i + \theta^s male_i + u_i^s$
#
# iii. $trader_i = \pi_0 + \pi_1 coffee_i + \pi_2 age_i + \pi_3 male_i + v_i$
#
# #### $stress$: stress level:; $coffee$: dummy variable equal to 1 iff coffee drinker, 0 otherwise; $age$: age; $male$: dummy variable equal to 1 if male, 0 if female; $trader$: dummy variable equal to 1 if working at the trading desk, 0 if working at the yoga studio
#
# - [x] Assuming our treatment is randomly assigned conditional on age, gender and workplace, the causal effect of coffee consumption on stress is equal to $ \hat \beta^l$
# - [ ] Zero conditional mean assumption is satisfied in regression ii.
# - [ ] Conditional expectation of $stress_i$ for 35 years old male coffee drinkers working at the trading desk is given by: $\alpha^i + \beta^l + \sigma^l 35$
# - [x] Omitted variable bias is equal to: $\hat \gamma^l \hat \pi_1$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 10. Suppose we have data on TV ad spening $(X_c)$ and revenue $(Y_c)$ for a movie about surfing. There are only two cities in the data set: Honolulu, Hawaii and Fargo, North Dakota. TV ad spending is $10M in Honolulu and $1M is Fargo. Movie revenue is $50M in Honolulu, and $5M in Fargo. Based on a regression of revenue ad spending, the production company estimates a $1M increase in ad spending is associated with a $5M increase in movie revenue.
#
# ### Which of the following omitted variables leads to an overestimation of the effect of ad spending on movie revenue (i.e. positive omitted variable bias)
#
# #### Hint: OVB = (“effect” of omitted on outcome) X (“effect” of included on omitted)
#
# - [ ] Critical reviews. (Suppose that the movie received more critical reviews in Honolulu than in Fargo and that fewer people watch movies that receive more critical reviews.)
# - [x] Interest in surfing.

# %% [markdown]
# ![image.png](attachment:image.png)
