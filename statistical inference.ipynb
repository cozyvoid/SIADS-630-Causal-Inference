# %% [markdown]
# #  Statistical Inference
#
# ---

# %% [markdown]
# ### Statistical Inference
#
# - The aim of statistical inference is to make statements about the population of interest using a sample of data from the population
#
# ![image.png](attachment:image.png)
#
# #### STEPS:
# 1. Estimate a population value
#     - What is the best estimate of the causal effect of health insurance on health?
# 2. Estimate precision of an estimate (standard error)
#     - What range of values can we be confident contains the true value for the causal effect of health insurance on health?
# 3. Hypothesis testing (p-value)
#     - Could the insurance effect we observed be attributed to chance?

# %% [markdown]
# ### Average Causal Effects
#
# ![image.png](attachment:image.png)
#
# - ATE is the average change in outcomes if *everybody* in the population were to go from untreated to treated
# - ATE is the average of the unit-level treatment effects
# - ATE is not a quantity we can calculate because we would need the counterfactual outcome for each individual -- but we can *estimate* it
#
# ![image-2.png](attachment:image-2.png)
#
# Conditional:
# - average causal effect for a particular subgroup in the population, such as women or low income individuals.
# - When estimating the conditional average treatment effect, we focus on people who have a certain value of the covariate X.
#
# Average treatment effect on the treated:
# - is the population average treatment effect for the group of individuals who receive the treatment.
# - the average treatment effect and the average treatment effect on the treated are usually not the same.
# - This is because the parameters are based on different segments of the population.
# - Just like other treatment effects, we cannot know the true value of the average treatment effect on the treated or the conditional average treatment effect because this would require us to have two observations per unit, but we only observe one.

# %% [markdown]
# ### Random Sampling
#
# - In estimating ATE, we rarely observe the entire population of interest → sample
# - We can draw a random sample of individuals and calculate the average outcome among those sampled
# - The sample average is a quantity that varies from sample to sample
# - But the expected value of the sample average equals the average of the population from which the sample is drawn

# %% [markdown]
# ### Expectations
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Conditional Expectations
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The Law of Large Numbers
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# **2**
#
# ![image-3.png](attachment:image-3.png)
#
# **4**
#
# ![image-4.png](attachment:image-4.png)
#
# **8**
#
# ![image-5.png](attachment:image-5.png)
#
# **100**
#
# ![image-6.png](attachment:image-6.png)
#
# **1000**

# %% [markdown]
# ### Sampling Distribution
#
# - Aim of statistical inference is to quantify the sample-to-sample variation
#
# - This variation is captured by the sampling distribution
#     - e.g., Distribution of sample means from repeated sampling
#     - Not to be confused with sample distribution (= distribution of individual observations in the sample)

# %% [markdown]
# ### Measuring Variability
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example – Student Health
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Random Sampling Variation
#
# - How does a sample mean compare to the population mean?
#     - Take a random sample from this population $(n = 10)$:
#     $$
#     [66, 62, 35, 50, 40, 30, 54, 91, 34, 66]
#     $$
#     - Is the sample mean close to the true population mean?
#         - Population mean: 50
#         - Sample mean: 52.8
#     - The difference is due to random sampling variation

# %% [markdown]
# ### Sampling Distribution
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Standard Error
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Standard Error vs. Standard Deviation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hypothesis Testing
#
# - Standard errors are used for confidence intervals (= range of plausible values for the parameter of interest)
# - Standard errors are also used for hypothesis testing:
#     - “What is the probability of getting a result as or more extreme than the sample result just by chance?”
#     - This probability is called p-value

# %% [markdown]
# ### The 3 Steps of Hypothesis Testing
#
# 1. Formulate the null hypothesis (and alternative hypothesis)
# 2. Calculate a test statistic (based on sample data)
# 3. Calculate a p-value using the probability distribution of the test statistic (and interpret the p-value considering the null hypothesis)

# %% [markdown]
# ### Example – Hypothesis Testing
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### t-Distribution and p-Value
#
# ![image.png](attachment:image.png)
