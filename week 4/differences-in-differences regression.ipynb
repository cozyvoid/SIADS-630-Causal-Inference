# %% [markdown]
# # Differences-in Differences Regression
#
# ---

# %% [markdown]
# ### More than 2 Periods
#
# - Revenue from Jan to Oct (price reduction from June to October in the U.S.):
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### DD Regression
#
# - Typical DD regression model:
# $$
#
# Y_{it} = \alpha + \beta TREAT_i + \gamma POST_t + \tau_{DD} (TREAT \times POST)_{it} + \epsilon_{it}
#
# $$
#
# - $Y_{it}$ is the outcome for unti $i$ at time $t$
# - $TREAT_i$ is a dummy equal to 1 if units are treated in the post-treatment period
# - $POST_t$ is a post-treatment dummy
# - $(TREAT \times POST)_{it}$ is an interaction term equal to 1 for the treatment group in the post-treatment period

# %% [markdown]
# - CAN Pre: $\alpha$
# - CAN Post: $\alpha + \gamma$
# - US Pre: $\alpha + \beta$
# - US Post: $\alpha + + \beta + \gamma + \tau_{DD}$
#
# DD estimate: (US Post = US Pre) - (CAN Post - Can Pre) = $\tau_{DD}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Multiple Groups, Multiple Periods
#
# - 5 treatment and 5 control groups (priced reduced in treat markets from June to October):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### DD Regression with Fixed Effects
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# - $COUNTRY_{ki}$ is a set of dummies for each country
# - $\beta_k$ capture time-invariant country fixed effects
# - $MONTH_{jt}$ is a set of dummies for each month
# - $\gamma_j$ capture time effects that are common to all countries
#
# - One group and one time fixed effect serves as the reference group (captured by $\alpha$) and has to be omitted

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - `treatXpost`: price reduction increases revenue (+13.7)
# - Output of country and month fixed effects is suppressed

# %% [markdown]
# ### Standard Errors in DD
#
# - Problem of serial correlation in DD applications:
#     - Many DD applications use data from many periods (not just 1 pre and 1 post period)
#     - Conventional standard errors tend to be downward biased because of serial correlation in the outcome variable (Bertrand et al. 2004)
# - Solutions:
#     - Clustered standard errors at the group level (>30 groups)
#     - Cluster (or block) bootstap standard errors (Cameron et al. 2008)
#     - Collapse time series into 1 pre and 1 post period for each group

# %% [markdown]
# ### Threats to Identification in DD Designs
#
# - Intervention is not as good as random
#     - Targeting based on pre-existing differences in outcomes
#     - e.g., price change in most promising markets
# - Some units are more likely to select into the treatment
#     - "Ashenfelter dip": people who participate in job training programs often experience a dip in earnings just before they enter the program (which is why they enroll)
#
# - Targeting or selection &rarr; parallel trends assumption might be violated

# %% [markdown]
# ### Non-Parallel Trends?
#
# - Dip in number of users in treat markets just before the price reduction is implemented:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Regression DD with Covariates
#
# - Parallel trends assumption may hold conditional on covariates
# - Add covariated in a linear, additive way:
#
# ![image.png](attachment:image.png)
#
# - $X_{it}$ is the number off users in country $i$ and month $t$

# %% [markdown]
# - `user`: revenue increases by 0.05 for each additional user
# - `treatXpost`: estimate is robust to controlling for the number of users
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Unit-Specific Linear Time Trends
#
# - With more than two periods, we can add unit-specific *linear* time trends to the regression model:
#
# ![image.png](attachment:image.png)
#
# - $t = 1, 2, ..., T$ is a linear time trend that increases by one for each month
#
# - While this relaxes the parallel trends assumption, we assume that the trends continue post treatment

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# - `tXcountry*`: country-specific linear time trends

# %% [markdown]
# ### Robustness Checks
#
# - What can we do to check for robustness of DD results?
#     - Include leads of the treatment (as if the treatment started in a prior period)
#     - Use alternative control groups that experience the same unit-specific time trends
#     - Use alternative outcomes that are not supposed to be affected by the treatment
